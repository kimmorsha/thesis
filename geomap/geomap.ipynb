# %%
import plotly.plotly as py
import pandas as pd

# %%
tweets_may = pd.read_csv("../dataset/01_may/marawi_tweets_05_24.csv", parse_dates=True,header=None)

# %%
tweets_may.head()
# Out:
#               0                 1   \
# 0      konkonmgt  2017-05-24 10:22
# 1    raefication  2017-05-24 23:59
# 2     HiImHappie  2017-05-24 23:59
# 3        yanaxxi  2017-05-24 23:58
# 4  tineChris9403  2017-05-24 23:58
#
#                                                   2   \
# 0  isis destroying marawi city the muslims area i...
# 1  terrorists in full throttle pray for jakarta n...
# 2  funny i am not blaming those who are actually ...
# 3  so sad that this happened prayformanchester al...
# 4  this is not about dutertardsyellowtards or eve...
#
#                                                   3   4         5         6   \
# 0  (['Republic of the Philippines'], Location((12...  en  0.415234  0.003960
# 1  (['Philippines'], Location((12.7503486, 122.73...  en  0.100389  0.012625
# 2  (['Philippines'], Location((12.7503486, 122.73...  en  0.477690  0.057940
# 3  (['Philippines'], Location((12.7503486, 122.73...  en  0.037899  0.005117
# ...

# %%
df[1] = df['airport'] + '' + df['city'] + ', ' + df['state'] + '' + 'Arrivals: ' + df['cnt'].astype(str)
